# %%
import pandas as pd
import external_func as ef
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt"
df_final_demo = pd.read_csv(url, sep=",")
df_final_demo.head(3)
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0

# %%
url_2 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt"
df_final_experiment_clients = pd.read_csv(url_2, sep=",")
df_final_experiment_clients.head(3)
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control

# %%
url_pt_1 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt"
df_pt_1 = pd.read_csv(url_pt_1)
df_pt_1.head(3)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22

# %%
url_pt_2 = "https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt"
df_pt_2 = pd.read_csv(url_pt_2)
df_pt_2.head(3)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48

# %% [markdown]
# ## Analysis of df_final_experiment_clients dataframe

# %%
df_final_experiment_clients.shape
# Out:
# (70609, 2)

# %%
df_final_experiment_clients.dtypes
# Out:
# client_id    int64
# Variation      str
# dtype: object

# %%
df_final_experiment_clients.isna().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
df_final_experiment_clients = ef.columns_formating(df_final_experiment_clients)
df_final_experiment_clients
# Out:
#        client_id variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_variation_nan = df_final_experiment_clients[df_final_experiment_clients["variation"].isna()]
df_variation_nan
# Out:
#        client_id variation
# 50500    5459747       NaN
# 50501    8031000       NaN
# 50502    1847030       NaN
# 50503    9713157       NaN
# 50504    7775828       NaN
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [20109 rows x 2 columns]

# %%
df_final_experiment_clients["variation"].value_counts()
# Out:
# variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df_final_experiment_clients["variation"].unique()
# Out:
# <StringArray>
# ['Test', 'Control', nan]
# Length: 3, dtype: str

# %% [markdown]
# **Conclusions:**
#
# - Data types are ok for this dataset
# - Besides NaN We have two values of "variation" variable: 'Test', 'Control'. We don't need to clear the data in this column
# - NaNs: 20109 -> 28,5% of dataset -> we're not aware of the participation of almost 30% of clients
# - Test: 26968 -> 38,2% of dataset -> approximately 38% of clients included in test group
# - Control: 23532 -> 33,32% of dataset -> approximately 33% of clients included in control group

# %% [markdown]
# ## Analysis of df_final_demo dataframe

# %%
df_final_demo.shape
# Out:
# (70609, 9)

# %%
df_final_demo.dtypes
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gendr                   str
# num_accts           float64
# bal                 float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# dtype: object

# %%
df_final_demo["gendr"].unique()
# Out:
# <StringArray>
# ['U', 'M', 'F', nan, 'X']
# Length: 5, dtype: str

# %% [markdown]
# **Conclusion.**
#  - M: Male / Man
#  - F: Female / Woman
#  - X: Non-binary, intersex, or gender-diverse
#  - U: Unspecified, unknown, or unrecorded

# %%
df_final_demo.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df_gender_nan = df_final_demo[df_final_demo["gendr"].isna()]
df_gender_nan
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164     7402828             NaN               NaN       NaN   NaN        NaN
# 8316      355337             NaN               NaN       NaN   NaN        NaN
# 8677     8412164             NaN               NaN       NaN   NaN        NaN
# 13444    2222915             NaN               NaN       NaN   NaN        NaN
# 18066    4876926             NaN               NaN       NaN   NaN        NaN
# 25961    5277910             NaN               NaN       NaN   NaN        NaN
# 28432    7616759             NaN               NaN       NaN   NaN        NaN
# 35323    8191345             NaN               NaN       NaN   NaN        NaN
# 43518    1227228             NaN               NaN       NaN   NaN        NaN
# 46076    8611797             NaN               NaN       NaN   NaN        NaN
# 47189    5144725             NaN               NaN       NaN   NaN        NaN
# ...

# %%
clients_without_group = df_final_demo[df_final_demo["client_id"].isin(df_variation_nan["client_id"])]
clients_without_group
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 50500     414870             6.0              80.0      57.0     U        2.0
# 50501    1047811             9.0             118.0      30.0     M        2.0
# 50502    6090170             5.0              62.0      28.0     U        2.0
# 50503     706631            16.0             193.0      56.0     U        2.0
# 50504    6844077            16.0             196.0      48.5     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %% [markdown]
# For two of them we have no information about their activity in the app

# %% [markdown]
# **Conclusions:**
# - We have 14 clients with empty data (by all rows)
# - Data types are ok for this dataset
# - Important to notice - we have 4 different options in "gender" category
# - Clients who participated in the experiment 'df_final_experiment_clients' without specifying a group can be found in the dataset 'df_final_demo'
#
# **Open questions:**
# - Can we identify criterias for spliting groups? -> Can identify the group for clients with NaNs from 'df_final_experiment_clients' -> Do we really need to identify the group for NaN
# - What client activity from 'df_final_demo' is more valuabl for us?

# %% [markdown]
# ### What can we say about the clients who participated/not participated in the test?

# %%
test_group = df_final_experiment_clients[df_final_experiment_clients["variation"] == "Test"]["client_id"]
test_group
# Out:
# 0        9988021
# 1        8320017
# 3        1982004
# 5        9466803
# 6        3170143
#           ...
# 50490    5969816
# 50492    8692087
# 50497    7230446
# 50498    5230357
# 50499    6334360
# Name: client_id, Length: 26968, dtype: int64

# %%
control_group = df_final_experiment_clients[df_final_experiment_clients["variation"] == "Control"]["client_id"]
control_group
# Out:
# 2        4033851
# 4        9294070
# 7        6651403
# 9        2105948
# 12       9814849
#           ...
# 50491    4364429
# 50493    8730282
# 50494    5305116
# 50495     393005
# 50496    2908510
# Name: client_id, Length: 23532, dtype: int64

# %%
not_participated_clients = df_final_demo[~df_final_demo["client_id"].isin(df_final_experiment_clients["client_id"])]
not_participated_clients
# Out:
# Empty DataFrame
# Columns: [client_id, clnt_tenure_yr, clnt_tenure_mnth, clnt_age, gendr, num_accts, bal, calls_6_mnth, logons_6_mnth]
# Index: []

# %% [markdown]
# **Conclusion 1**
#
# We can say, that all clients from df_final_demo are participated in test. We need to identify the groups for NaN client_id's

# %%
clients_in_test_gr = df_final_demo[df_final_demo["client_id"].isin(test_group)]
clients_in_test_gr
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 7         388801            30.0             361.0      57.5     M        5.0
# 9        8198645            15.0             189.0      54.5     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50492     501496            23.0             281.0      35.0     F        2.0
# 50495    1780858            21.0             262.0      68.5     M        3.0
# 50497    5826160            20.0             249.0      56.5     F        2.0
# 50498    8739285            19.0             229.0      69.5     F        2.0
# 50499    7468138            18.0             222.0      61.0     F        3.0
#
# ...

# %%
clients_in_control_gr = df_final_demo[df_final_demo["client_id"].isin(control_group)]
clients_in_control_gr
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 1        2304905             7.0              94.0      58.0     U        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# 5        3727881             5.0              71.0      30.5     U        2.0
# 6         272934             5.0              66.0      58.5     U        2.0
# 8         285619            30.0             369.0      67.5     M        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50486    6662941             7.0              84.0      36.0     F        2.0
# 50491    2787512            23.0             283.0      48.0     F        3.0
# 50493    9932367            23.0             280.0      57.0     F        2.0
# 50494    4079649            23.0             276.0      62.5     M        3.0
# 50496    6967120            21.0             260.0      68.5     M        3.0
#
# ...

# %%
clients_without_group[["clnt_tenure_yr", "clnt_tenure_mnth", "clnt_age", "num_accts", "bal", "calls_6_mnth", "logons_6_mnth"]].describe()
# Out:
#        clnt_tenure_yr  clnt_tenure_mnth      clnt_age     num_accts  \
# count    20107.000000      20107.000000  20107.000000  20107.000000
# mean        12.106232        151.271746     44.238773      2.257920
# std          6.900585         82.451745     15.555909      0.538317
# min          2.000000         33.000000     13.500000      1.000000
# 25%          6.000000         82.000000     30.500000      2.000000
# 50%         11.000000        138.000000     45.000000      2.000000
# 75%         16.000000        193.000000     56.500000      2.000000
# max         62.000000        749.000000     92.500000      8.000000
#
#                 bal  calls_6_mnth  logons_6_mnth
# count  2.010700e+04  20107.000000   20107.000000
# mean   1.422490e+05      4.108619       4.147710
# std    3.001242e+05      2.192047       2.178329
# min    1.378942e+04      1.000000       1.000000
# 25%    3.014772e+04      2.000000       2.000000
# 50%    5.633810e+04      4.000000       4.000000
# ...

# %%
clients_in_test_gr[["clnt_tenure_yr", "clnt_tenure_mnth", "clnt_age", "num_accts", "bal", "calls_6_mnth", "logons_6_mnth"]].describe()
# Out:
#        clnt_tenure_yr  clnt_tenure_mnth      clnt_age     num_accts  \
# count    26961.000000      26961.000000  26961.000000  26961.000000
# mean        11.982901        149.852899     47.163922      2.249917
# std          6.844947         81.783390     15.514461      0.529335
# min          2.000000         33.000000     17.000000      1.000000
# 25%          6.000000         82.000000     33.500000      2.000000
# 50%         11.000000        134.000000     47.500000      2.000000
# 75%         15.000000        191.000000     59.500000      2.000000
# max         55.000000        669.000000     96.000000      7.000000
#
#                 bal  calls_6_mnth  logons_6_mnth
# count  2.696100e+04  26961.000000   26961.000000
# mean   1.489626e+05      3.061941       6.101851
# std    3.073737e+05      2.190590       2.177119
# min    2.378944e+04      0.000000       3.000000
# 25%    3.972920e+04      1.000000       4.000000
# 50%    6.546836e+04      3.000000       6.000000
# ...

# %%
clients_in_control_gr[["clnt_tenure_yr", "clnt_tenure_mnth", "clnt_age", "num_accts", "bal", "calls_6_mnth", "logons_6_mnth"]].describe()
# Out:
#        clnt_tenure_yr  clnt_tenure_mnth      clnt_age     num_accts  \
# count    23527.000000      23527.000000  23526.000000  23527.000000
# mean        12.087686        151.060186     47.498427      2.259914
# std          6.877531         82.126443     15.521781      0.538559
# min          2.000000         33.000000     17.000000      2.000000
# 25%          6.000000         82.000000     33.500000      2.000000
# 50%         11.000000        137.000000     48.500000      2.000000
# 75%         16.000000        192.000000     60.000000      2.000000
# max         55.000000        669.000000     96.000000      7.000000
#
#                 bal  calls_6_mnth  logons_6_mnth
# count  2.352700e+04  23527.000000   23527.000000
# mean   1.501473e+05      3.129213       6.166277
# std    2.958070e+05      2.184502       2.173014
# min    2.378961e+04      0.000000       3.000000
# 25%    4.012335e+04      1.000000       4.000000
# 50%    6.602418e+04      3.000000       6.000000
# ...

# %%
display(clients_without_group.isna().sum())
display(clients_in_test_gr.isna().sum())
display(clients_in_control_gr.isna().sum())
# Out:
# client_id           0
# clnt_tenure_yr      2
# clnt_tenure_mnth    2
# clnt_age            2
# gendr               2
# num_accts           2
# bal                 2
# calls_6_mnth        2
# logons_6_mnth       2
# dtype: int64
# client_id           0
# clnt_tenure_yr      7
# clnt_tenure_mnth    7
# clnt_age            7
# gendr               7
# num_accts           7
# bal                 7
# calls_6_mnth        7
# logons_6_mnth       7
# dtype: int64
# client_id           0
# clnt_tenure_yr      5
# clnt_tenure_mnth    5
# clnt_age            6
# gendr               5
# num_accts           5
# bal                 5
# calls_6_mnth        5
# logons_6_mnth       5
# dtype: int64

# %% [markdown]
# **Conclusion 2**
#
# We have three gpoups of clients: in "test" group, in "control" group and without group_name. We can see almost the same statistical data for each group
#
# **Conclusion 3**
# We have a missing values for 14 clients. We need to clarify, if we need to drop them or they have a valuable data

# %% [markdown]
# ## Analysis for df_final_web_data

# %%
df_pt_1.shape
# Out:
# (343141, 5)

# %%
df_pt_1.isna().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_pt_1.duplicated().sum()
# Out:
# np.int64(2095)

# %%
df_pt_2.shape
# Out:
# (412264, 5)

# %%
df_pt_2.isna().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_pt_2.duplicated().sum()
# Out:
# np.int64(8669)

# %%
merged_df = pd.merge(df_pt_2, df_pt_1, on=["client_id", "visitor_id", "visit_id", "process_step", "date_time"], how='outer')
merged_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             169  201385055_71273495308  749567106_99161211863_557568
# 1             169  201385055_71273495308  749567106_99161211863_557568
# 2             169  201385055_71273495308  749567106_99161211863_557568
# 3             169  201385055_71273495308  749567106_99161211863_557568
# 4             169  201385055_71273495308  749567106_99161211863_557568
# ...           ...                    ...                           ...
# 755400    9999875   738878760_1556639849    931268933_219402947_599432
# 755401    9999875   738878760_1556639849    931268933_219402947_599432
# 755402    9999875   738878760_1556639849    931268933_219402947_599432
# 755403    9999875   738878760_1556639849    931268933_219402947_599432
# 755404    9999875   738878760_1556639849    931268933_219402947_599432
#
#        process_step            date_time
# 0           confirm  2017-04-12 20:23:09
# ...

# %%
merged_df["date_time"] = pd.to_datetime(merged_df["date_time"])

# %%
merged_df.dtypes
# Out:
# client_id                int64
# visitor_id                 str
# visit_id                   str
# process_step               str
# date_time       datetime64[us]
# dtype: object

# %%
merged_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             169  201385055_71273495308  749567106_99161211863_557568
# 1             169  201385055_71273495308  749567106_99161211863_557568
# 2             169  201385055_71273495308  749567106_99161211863_557568
# 3             169  201385055_71273495308  749567106_99161211863_557568
# 4             169  201385055_71273495308  749567106_99161211863_557568
# ...           ...                    ...                           ...
# 755400    9999875   738878760_1556639849    931268933_219402947_599432
# 755401    9999875   738878760_1556639849    931268933_219402947_599432
# 755402    9999875   738878760_1556639849    931268933_219402947_599432
# 755403    9999875   738878760_1556639849    931268933_219402947_599432
# 755404    9999875   738878760_1556639849    931268933_219402947_599432
#
#        process_step           date_time
# 0           confirm 2017-04-12 20:23:09
# ...

# %%
print(merged_df["client_id"].isna().sum())
print(merged_df["visitor_id"].isna().sum())
print(merged_df["visit_id"].isna().sum())
print(merged_df["process_step"].isna().sum())
print(merged_df["date_time"].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(10764)

# %%
343141+412264
# Out:
# 755405

# %% [markdown]
# **Conclusion:**
# - After merging we've got dataframe with data from df_pt_1 and df_pt_2
# - The amount of potential duplicates is a bit more than a sum of duplicates from each dataset

# %%
#nan_group_clients = merged_df[merged_df["client_id"].isin(df_variation_nan["client_id"])]
#nan_group_clients.shape

# %% [markdown]
# Here we have information about client activity with NaN group name and after filtering out duplicated rows:

# %%
#nan_group_clients[nan_group_clients.duplicated(subset=['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time']) == True]

# %%
#nan_group = nan_group_clients[nan_group_clients.duplicated(subset=['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time']) == False]
#nan_group.shape

# %%
#test_group_clients = merged_df[merged_df["client_id"].isin(test_group)]
#test_group_clients.shape

# %% [markdown]
# Here we have information about client activity with 'Test' group name and after filtering out duplicated rows:

# %%
#test_group = test_group_clients[test_group_clients.duplicated(subset=['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time']) == False]
#test_group.shape

# %%
#control_group_clients = merged_df[merged_df["client_id"].isin(test_group)]
#control_group_clients.shape

# %% [markdown]
# Here we have information about client activity with 'Control' group name and after filtering out duplicated rows:

# %%
#control_group = control_group_clients[control_group_clients.duplicated(subset=['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time']) == False]
#control_group.shape

# %% [markdown]
# **Conclusion**
# - We have activity for all 14 clients. But at this step we're not sure if we have valuable data for all of them -> we can't drop clients witn NaN client info

# %%
#test_group.head(3)

# %%
#test_group["t_combo_id"] = (test_group["client_id"].astype(str)+"-"+test_group["visitor_id"].astype(str)+"-"+test_group["visit_id"].astype(str))
#test_group

# %%
#control_group["contr_combo_id"] = (control_group["client_id"].astype(str)+"-"+control_group["visitor_id"].astype(str)+"-"+control_group["visit_id"].astype(str))
#control_group

# %%
#grouped_activities = test_group.groupby(['process_step']).agg(test_cnt_client=('t_combo_id', 'count'))
#grouped_activities

# %%
#control_groupped_activities = control_group.groupby(['process_step']).agg(control_cnt_client=('contr_combo_id', 'count'))
#control_groupped_activities

# %%
# KPI's
# The time online
# the amount of click's

# %%
#Here we can find activity of 14 clients, who has no data in 'df_final_demo'
merged_df_copy = merged_df[merged_df["client_id"].isin(df_gender_nan["client_id"])]
merged_df_copy["client_id"].value_counts()

# %% [markdown]
# ## Explore the distribution of the digital engagement variables

# %% [markdown]
# Digital engagement variables are: 'clnt_tenure_yr', 'clnt_tenure_mnth', 'num_accts', 'logons_6_mnth'

# %% [markdown]
# 1) "Logon" metric for test group and control group:

# %%
clients_in_test_gr
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 7         388801            30.0             361.0      57.5     M        5.0
# 9        8198645            15.0             189.0      54.5     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50492     501496            23.0             281.0      35.0     F        2.0
# 50495    1780858            21.0             262.0      68.5     M        3.0
# 50497    5826160            20.0             249.0      56.5     F        2.0
# 50498    8739285            19.0             229.0      69.5     F        2.0
# 50499    7468138            18.0             222.0      61.0     F        3.0
#
# ...

# %%
clients_in_test_gr.logons_6_mnth.value_counts()
# Out:
# logons_6_mnth
# 9.0    6491
# 4.0    4302
# 3.0    3993
# 5.0    3803
# 6.0    3233
# 7.0    2619
# 8.0    2520
# Name: count, dtype: int64

# %%
clients_in_control_gr.logons_6_mnth.value_counts()
# Out:
# logons_6_mnth
# 9.0    5859
# 4.0    3553
# 5.0    3480
# 3.0    3318
# 6.0    2732
# 7.0    2295
# 8.0    2290
# Name: count, dtype: int64

# %%
clients_in_test_gr[["client_id", "logons_6_mnth"]]
# Out:
#        client_id  logons_6_mnth
# 0         836976            9.0
# 2        1439522            9.0
# 3        1562045            6.0
# 7         388801            4.0
# 9        8198645            9.0
# ...          ...            ...
# 50492     501496            3.0
# 50495    1780858            9.0
# 50497    5826160            5.0
# 50498    8739285            4.0
# 50499    7468138            3.0
#
# [26968 rows x 2 columns]

# %%
clients_in_control_gr[["client_id", "logons_6_mnth"]]
# Out:
#        client_id  logons_6_mnth
# 1        2304905            9.0
# 4        5126305            3.0
# 5        3727881            3.0
# 6         272934            5.0
# 8         285619            6.0
# ...          ...            ...
# 50486    6662941            7.0
# 50491    2787512            4.0
# 50493    9932367            9.0
# 50494    4079649            7.0
# 50496    6967120            9.0
#
# [23532 rows x 2 columns]

# %%
sns.boxplot(data=clients_in_test_gr, x='logons_6_mnth', y='client_id', palette="coolwarm", hue='logons_6_mnth', legend=False);

# %%
sns.boxplot(data=clients_in_control_gr, x='logons_6_mnth', y='client_id', palette="coolwarm", hue='logons_6_mnth', legend=False);

# %% [markdown]
# **Conclusion**
# We have perfectly distributed groups of clients by "Logon" metric

# %%
2)

# %%
merged_df["combo_id"] = (merged_df["client_id"].astype(str)+"-"+merged_df["visitor_id"].astype(str)+"-"+merged_df["visit_id"].astype(str))
merged_df["process_step"].value_counts()
# Out:
# process_step
# start      243945
# step_1     163193
# step_2     133062
# step_3     112242
# confirm    102963
# Name: count, dtype: int64

# %%
merged_df["process_step"] = merged_df["process_step"].map({'start': 0, 'step_1': 1, 'step_2': 2, 'step_3': 3, 'confirm': 4})

# %%
# t_activity - 'df_final_web_data' without session info
t_activity = merged_df[merged_df["client_id"].isin(clients_in_test_gr["client_id"])]

# grouped_t - getting sessions from 'date_time' column into 
grouped_t = t_activity.groupby(['visit_id'], as_index=False).agg(d_max=('date_time', 'max'), d_min=('date_time', 'min'))
grouped_t['session_minutes'] = (grouped_t['d_max'] - grouped_t['d_min']).dt.total_seconds() / 60

# joining dataset t_activity + grouped_t -> we're getting 'session_minutes', 'd_max', 'd_min' instead 'date_time' column
t_activity_final = t_activity.set_index("visit_id").join(grouped_t.set_index("visit_id"), how='inner')
t_activity_final = t_activity_final.reset_index()
t_activity_final
# Out:
#                             visit_id  client_id             visitor_id  \
# 0       637149525_38041617439_716659        555  402506806_56087378777
# 1       637149525_38041617439_716659        555  402506806_56087378777
# 2       637149525_38041617439_716659        555  402506806_56087378777
# 3       637149525_38041617439_716659        555  402506806_56087378777
# 4       637149525_38041617439_716659        555  402506806_56087378777
# ...                              ...        ...                    ...
# 177842   493310979_9209676464_421146    9999729  843385170_36953471821
# 177843   493310979_9209676464_421146    9999729  843385170_36953471821
# 177844   493310979_9209676464_421146    9999729  843385170_36953471821
# 177845  472154369_16714624241_585315    9999832  145538019_54444341400
# 177846  472154369_16714624241_585315    9999832  145538019_54444341400
#
#         process_step           date_time  \
# 0                  4 2017-04-15 13:00:34
# ...

# %%
t_activity
# Out:
#         client_id             visitor_id                      visit_id  \
# 12            555  402506806_56087378777  637149525_38041617439_716659
# 13            555  402506806_56087378777  637149525_38041617439_716659
# 14            555  402506806_56087378777  637149525_38041617439_716659
# 15            555  402506806_56087378777  637149525_38041617439_716659
# 16            555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 755376    9999729  843385170_36953471821   493310979_9209676464_421146
# 755377    9999729  843385170_36953471821   493310979_9209676464_421146
# 755378    9999729  843385170_36953471821   493310979_9209676464_421146
# 755391    9999832  145538019_54444341400  472154369_16714624241_585315
# 755392    9999832  145538019_54444341400  472154369_16714624241_585315
#
#         process_step           date_time  \
# 12                 4 2017-04-15 13:00:34
# ...

# %%
t_activity_final.describe()
# Out:
#           client_id   process_step                       d_max  \
# count  1.778470e+05  177847.000000                      177847
# mean   5.005555e+06       1.581787  2017-04-18 07:36:06.521346
# min    5.550000e+02       0.000000         2017-03-15 00:44:38
# 25%    2.506130e+06       0.000000  2017-04-03 17:33:17.500000
# 50%    5.061459e+06       1.000000         2017-04-12 11:45:21
# 75%    7.474303e+06       3.000000         2017-04-24 13:12:26
# max    9.999832e+06       4.000000         2017-06-20 23:21:23
# std    2.879374e+06       1.427369                         NaN
#
#                             d_min  session_minutes
# count                      177847    177847.000000
# mean   2017-04-18 07:27:47.250293         8.321184
# min           2017-03-15 00:43:23         0.000000
# 25%           2017-04-03 17:26:19         2.316667
# 50%           2017-04-12 11:35:58         4.450000
# 75%           2017-04-24 13:02:52         9.000000
# ...

# %%
joined_data_test = t_activity_final.set_index("client_id").join(clients_in_test_gr.set_index("client_id"), how='inner')
correlation_1 = joined_data_test['session_minutes'].corr(joined_data_test['logons_6_mnth'])
correlation_1
# Out:
# np.float64(-0.01877989389639609)

# %%
joined_data_test_num = joined_data_test[["session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "clnt_age", "num_accts", "calls_6_mnth", ""]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 joined_data_test_num = joined_data_test[["session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "clnt_age", "num_accts", "calls_6_mnth", ""]]
#
# File ~/IronHack/Week_6/Day_1/second_project/.venv/lib/python3.14/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
control_activ = merged_df[merged_df["client_id"].isin(clients_in_control_gr["client_id"])]
control_activ
# Out:
#         client_id             visitor_id                      visit_id  \
# 57           1028   42237450_62128060588  557292053_87239438319_391157
# 58           1028   42237450_62128060588  557292053_87239438319_391157
# 59           1028   42237450_62128060588  557292053_87239438319_391157
# 60           1028   42237450_62128060588  557292053_87239438319_391157
# 61           1028   42237450_62128060588  557292053_87239438319_391157
# ...           ...                    ...                           ...
# 755271    9998346  292425655_16607136645  189177304_69869411700_783154
# 755272    9998346  292425655_16607136645  189177304_69869411700_783154
# 755273    9998346  292425655_16607136645  189177304_69869411700_783154
# 755274    9998346  292425655_16607136645  189177304_69869411700_783154
# 755326    9998921  960034051_85687824805    378424178_59565976155_8051
#
#         process_step           date_time  \
# 57                 0 2017-04-08 18:51:28
# ...

# %%
control_activ_sorted = control_activ.sort_values(by=['visit_id', 'date_time'])
control_activ_sorted
# Out:
#         client_id             visitor_id                      visit_id  \
# 8183       105007  676020267_36602664238  100030127_47967100085_936361
# 422818    5623007  700426174_33289797318  100037962_47432393712_705583
# 422819    5623007  700426174_33289797318  100037962_47432393712_705583
# 422821    5623007  700426174_33289797318  100037962_47432393712_705583
# 422820    5623007  700426174_33289797318  100037962_47432393712_705583
# ...           ...                    ...                           ...
# 305004    4064969  110735946_42614968419  999985675_64610694964_443659
# 305005    4064969  110735946_42614968419  999985675_64610694964_443659
# 305006    4064969  110735946_42614968419  999985675_64610694964_443659
# 305007    4064969  110735946_42614968419  999985675_64610694964_443659
# 305003    4064969  110735946_42614968419  999985675_64610694964_443659
#
#         process_step           date_time  \
# 8183               0 2017-03-22 11:07:49
# ...

# %%
gr_s_activities = control_activ_sorted.groupby(['client_id','visit_id'])['date_time'].agg(['min', 'max'])
gr_s_activities['session_minutes'] = (gr_s_activities['max'] - gr_s_activities['min']).dt.total_seconds() / 60
gr_s_activities.describe()
# Out:
#                               min                         max  session_minutes
# count                       32243                       32243     32243.000000
# mean   2017-04-21 15:49:41.882858  2017-04-21 15:54:22.393511         4.675178
# min           2017-03-15 00:19:28         2017-03-15 00:26:24         0.000000
# 25%    2017-04-05 11:09:16.500000         2017-04-05 11:12:44         0.366667
# 50%           2017-04-12 15:43:30         2017-04-12 15:48:11         2.666667
# 75%    2017-05-05 17:07:07.500000  2017-05-05 17:11:42.500000         5.683333
# max           2017-06-20 23:56:17         2017-06-20 23:57:06       699.416667
# std                           NaN                         NaN         8.826008

# %%
gr_s_activities = gr_s_activities.reset_index()

# %%
fig, ax = plt.subplots()
t_activity_final.plot.scatter(x='client_id', y='session_minutes', color='blue', label='Test group session duration', ax=ax)
gr_s_activities.plot.scatter(x='client_id', y='session_minutes', color='red', label='Control group session duration', ax=ax)
plt.show()

# %%
joined_data_control = gr_s_activities.set_index("client_id").join(clients_in_control_gr.set_index("client_id"), how='inner')
correlation_2 = joined_data_control['session_minutes'].corr(joined_data_control['logons_6_mnth'])
correlation_2
# Out:
# np.float64(-0.04179559519435589)

# %%
joined_data_control_num = joined_data_control[["session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "clnt_age", "num_accts", "calls_6_mnth", "logons_6_mnth"]]

# %%
corr_control = joined_data_control_num.corrwith(joined_data_control['session_minutes'], method='pearson')
corr_control
# Out:
# session_minutes     1.000000
# clnt_tenure_yr      0.008811
# clnt_tenure_mnth    0.008830
# clnt_age            0.067716
# num_accts          -0.030764
# calls_6_mnth       -0.043413
# logons_6_mnth      -0.041796
# dtype: float64

# %%
corr_test = joined_data_test_num.corrwith(joined_data_test['session_minutes'], method='pearson')
corr_test
# Out:
# session_minutes     1.000000
# clnt_tenure_yr      0.018710
# clnt_tenure_mnth    0.019590
# clnt_age            0.102497
# num_accts          -0.013146
# calls_6_mnth       -0.020581
# logons_6_mnth      -0.018780
# dtype: float64

# %%
joined_data_control = joined_data_control.reset_index()
joined_data_test = joined_data_test.reset_index()

# %%
test_dataset = joined_data_test[["session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "num_accts", "logons_6_mnth"]]
control_dataset = joined_data_control[["session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "num_accts", "logons_6_mnth"]]

# %%
test_dataset.shape

# %%
test_dataset.isna().sum()

# %%
test_dataset = test_dataset.dropna(subset=["clnt_tenure_yr", "clnt_tenure_mnth", "num_accts", "logons_6_mnth"])

# %%
test_dataset.isna().sum()

# %%
control_dataset.shape

# %%
control_dataset.isna().sum()

# %%
control_dataset = control_dataset.dropna(subset=["clnt_tenure_yr", "clnt_tenure_mnth", "num_accts", "logons_6_mnth"])

# %%
control_dataset.isna().sum()

# %%
# H0 - datasets are equal
# H1 - datasets have some diferencies 
alpha = 0.05
_, p_value = st.ttest_ind(test_dataset, control_dataset, equal_var=False)

# %%
# columns used for t-test: "session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "num_accts", "logons_6_mnth"
for p in p_value:
    if p > alpha:
        print("We are not able to reject the null hypothesis. p_value is", p)
    else:
        print("We reject the null hypothesis. p_value is", p)

# %%
test_dataset = joined_data_test[["session_minutes", "clnt_tenure_yr", "clnt_tenure_mnth", "num_accts", "logons_6_mnth"]]

# %% [markdown]
# **Conclusions**
# - After AB-test we have some diffirences for metricks: 'session_minutes', 'num_accts', 'logons_6_mnth'

# %%
fig, axes = plt.subplots()
sns.histplot(test_dataset['session_minutes'], bins=50, color="salmon", ax=axes);
sns.histplot(control_dataset['session_minutes'], bins=50, color="skyblue", ax=axes);
plt.show()

# %%
fig, axes = plt.subplots()
sns.histplot(test_dataset['session_minutes'], stat="density", bins=50, color="salmon", ax=axes, log_scale=True);
sns.histplot(control_dataset['session_minutes'],stat="density", bins=50, color="skyblue", ax=axes, log_scale=True);
plt.show()

# %% [markdown]
# **Conclusions**
# - we have almost the same amount of short sessions (with duration about 0 minutes)
# - in test group we decreased amount of long sessions

# %%
fig, axes = plt.subplots()
sns.histplot(test_dataset['num_accts'], bins=50, color="salmon", ax=axes);
sns.histplot(control_dataset['num_accts'], bins=50, color="skyblue", ax=axes);
plt.show()

# %%
fig, axes = plt.subplots()
sns.histplot(test_dataset['logons_6_mnth'], bins=50, color="salmon", ax=axes);
sns.histplot(control_dataset['logons_6_mnth'], bins=50, color="skyblue", ax=axes);
plt.show()

# %% [markdown]
# the number of logins has increased for all group of clients
